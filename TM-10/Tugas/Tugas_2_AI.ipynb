# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

data = pd.read_excel("AirQualityUCI.xlsx")
df = pd.DataFrame(data)
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# ...

# %%
# Ambil kolom NMHC dan RH
X = data['NMHC(GT)']
y = data['RH']

# Klasterisasi menggunakan KMeans
kmeans = KMeans(n_clusters=5).fit(X)
labels = kmeans.labels_

# Plot hasil klaster 
plt.scatter(X, y, c=labels, cmap='rainbow')

centers = kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], color='black', marker='*', label='centroid')

plt.title('Hasil Klasterisasi Data Kualitas Udara')
plt.xlabel('NMHC')
plt.ylabel('RH')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18664/1197163587.py in <module>
#       5
#       6 # Klasterisasi menggunakan KMeans
# ----> 7 kmeans = KMeans(n_clusters=5).fit(X)
#       8 labels = kmeans.labels_
#       9
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1138             Fitted estimator.
#    1139         """
# -> 1140         X = self._validate_data(
#    1141             X,
#    1142             accept_sparse="csr",
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     559             raise ValueError("Validation should be done on X, y or both.")
#     560         elif not no_val_X and no_val_y:
# --> 561             X = check_array(X, **check_params)
# ...
